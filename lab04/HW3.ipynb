# %% [markdown]
# Реализуйте алгоритм GAIL на среде Mountain Car. Перед этим сгенерируйте экспертные данные (из детерминированной стратегии с первой практики). Хорошей идеей будет добавить в state (observation) синус и косинус от временной метки t для лучшего обучения.

# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions.categorical import Categorical

# %%
def generate_expert_data(num_episodes=200):
    env = gym.make("MountainCar-v0", render_mode=None)
    expert_states = []
    expert_actions = []
    successful_episodes = 0

    while successful_episodes < num_episodes:
        state, _ = env.reset()
        episode_states = []
        episode_actions = []
        done = False
        t = 0

        while not done:
            position, velocity = state
            if position < -0.5:
                action = 2  # Вправо
            elif position > 0.5:
                action = 0  # Влево
            else:
                action = 2 if velocity > 0 else 0

            next_state, _, terminated, truncated, _ = env.step(action)
            done = terminated or truncated

            # Добавляем временные метки
            augmented_state = np.concatenate([
                state,
                [np.sin(t / 10), np.cos(t / 10)]
            ]).astype(np.float32)

            episode_states.append(augmented_state)
            episode_actions.append(action)
            state = next_state
            t += 1

        if t < 200:
            expert_states.extend(episode_states)
            expert_actions.extend(episode_actions)
            successful_episodes += 1

    env.close()
    return np.array(expert_states), np.array(expert_actions)

# %%
states, actions = generate_expert_data() # Получите экспертные данные

# %%
# исправьте для среды mountain car и учтите добавление данных в state
obs_dim = 4  # [position, velocity, sin(t/10), cos(t/10)]
# исправьте для среды mountain car
act_dim = 3  # 3 действия (0: влево, 1: нет газа, 2: вправо)
expert_obs = np.copy(states)
expert_acts = np.copy(actions)

# %%
class Policy(nn.Module):
    def __init__(self, obs_dim, act_dim):
        super().__init__()
        # self.net = nn.Sequential(
        #     nn.Linear(obs_dim, 64), nn.ReLU(),
        #     nn.Linear(64, act_dim)
        # )
        self.net = nn.Sequential(
            nn.Linear(obs_dim, 64), nn.ReLU(),
            nn.Linear(64, 64), nn.ReLU(),
            nn.Linear(64, act_dim)
        )

    def forward(self, obs):
        logits = self.net(obs)
        return Categorical(logits=logits)

    def get_action(self, obs):
        dist = self.forward(obs)
        return dist.sample().item()

# %%
class Discriminator(nn.Module):
    def __init__(self, obs_dim, act_dim):
        super().__init__()
        # self.net = nn.Sequential(
        #     nn.Linear(obs_dim + act_dim, 64), nn.ReLU(),
        #     nn.Linear(64, 1),
        #     nn.Sigmoid()
        # )
        self.net = nn.Sequential(
            nn.Linear(obs_dim + act_dim, 64), nn.ReLU(),
            nn.Linear(64, 64), nn.ReLU(),
            nn.Linear(64, 1),
            nn.Sigmoid()
        )

    def forward(self, obs, act):
        act_onehot = F.one_hot(act, num_classes=act_dim).float()
        x = torch.cat([obs, act_onehot], dim=1)
        return self.net(x)

# %%
class TrajectoryBuffer:
    def __init__(self):
        self.obs, self.acts, self.rews = [], [], []

    def store(self, o, a, r):
        self.obs.append(o)
        self.acts.append(a)
        self.rews.append(r)

    def get(self):
        return (
            torch.tensor(np.array(self.obs), dtype=torch.float32),
            torch.tensor(np.array(self.acts), dtype=torch.long),
            torch.tensor(np.array(self.rews), dtype=torch.float32)
        )

# %%
env = gym.make("MountainCar-v0", )
policy = Policy(obs_dim, act_dim)
discrim = Discriminator(obs_dim, act_dim)

policy_opt = optim.Adam(policy.parameters(), lr=1e-3)
discrim_opt = optim.Adam(discrim.parameters(), lr=1e-3)

# %%
for epoch in range(3000):
    buf = TrajectoryBuffer()
    obs, _ = env.reset()
    done = False
    total_reward = 0
    t = 0

    while not done:
        # Обработайте obs если планируете добавлять в него t
        augmented_obs = np.concatenate([
            obs,
            [np.sin(t / 10), np.cos(t / 10)]
        ]).astype(np.float32)
        obs_tensor = torch.tensor(augmented_obs, dtype=torch.float32).unsqueeze(0)
        action = policy.get_action(obs_tensor)
        next_obs, _, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

        buf.store(augmented_obs, action, 0)
        obs = next_obs
        t += 1

    agent_obs, agent_acts, _ = buf.get()

    idxs = np.random.choice(len(expert_obs), len(agent_obs), replace=False)
    exp_obs = torch.tensor(expert_obs[idxs], dtype=torch.float32)
    exp_acts = torch.tensor(expert_acts[idxs], dtype=torch.long)

    for _ in range(2):
        discrim_opt.zero_grad()
        
        exp_preds = discrim(exp_obs, exp_acts)
        agent_preds = discrim(agent_obs, agent_acts)
        
        # Напишите loss для дискриминатора
        disc_loss = -torch.mean(torch.log(exp_preds + 1e-8) + torch.log(1 - agent_preds + 1e-8))

        disc_loss.backward()
        discrim_opt.step()

    with torch.no_grad():
        # Напишите получение новой награды от дискриминатора
        rewards = -torch.log(1 - discrim(agent_obs, agent_acts) + 1e-8).squeeze()

    policy_opt.zero_grad()
    # Напишите loss для стратегии
    dists = policy(agent_obs)
    log_probs = dists.log_prob(agent_acts)
    loss = -(log_probs * rewards).mean()
    
    loss.backward()
    policy_opt.step()

    if epoch % 10 == 0:
        print(f"Epoch {epoch}: GAIL Loss {loss.item():.3f}, Disc Loss {disc_loss.item():.3f}")
# Out:
# Epoch 0: GAIL Loss 0.780, Disc Loss 1.376
# Epoch 10: GAIL Loss 0.709, Disc Loss 1.293
# Epoch 20: GAIL Loss 0.575, Disc Loss 1.174
# Epoch 30: GAIL Loss 0.388, Disc Loss 1.198
# Epoch 40: GAIL Loss 0.217, Disc Loss 1.232
# Epoch 50: GAIL Loss 0.237, Disc Loss 1.268
# Epoch 60: GAIL Loss 0.150, Disc Loss 1.201
# Epoch 70: GAIL Loss 0.206, Disc Loss 1.143
# Epoch 80: GAIL Loss 0.233, Disc Loss 1.107
# Epoch 90: GAIL Loss 0.285, Disc Loss 1.251
# Epoch 100: GAIL Loss 0.203, Disc Loss 1.054
# Epoch 110: GAIL Loss 0.264, Disc Loss 1.203
# Epoch 120: GAIL Loss 0.200, Disc Loss 1.073
# Epoch 130: GAIL Loss 0.306, Disc Loss 1.203
# Epoch 140: GAIL Loss 0.208, Disc Loss 1.090
# Epoch 150: GAIL Loss 0.176, Disc Loss 1.001
# Epoch 160: GAIL Loss 0.208, Disc Loss 1.016
# Epoch 170: GAIL Loss 0.213, Disc Loss 1.062
# Epoch 180: GAIL Loss 0.191, Disc Loss 0.993
# Epoch 190: GAIL Loss 0.260, Disc Loss 1.137
# Epoch 200: GAIL Loss 0.154, Disc Loss 0.978
# Epoch 210: GAIL Loss 0.241, Disc Loss 1.234
# Epoch 220: GAIL Loss 0.206, Disc Loss 1.084
# Epoch 230: GAIL Loss 0.221, Disc Loss 1.090
# Epoch 240: GAIL Loss 0.252, Disc Loss 1.300
# Epoch 250: GAIL Loss 0.160, Disc Loss 1.017
# Epoch 260: GAIL Loss 0.191, Disc Loss 1.159
# Epoch 270: GAIL Loss 0.146, Disc Loss 0.879
# Epoch 280: GAIL Loss 0.117, Disc Loss 0.926
# Epoch 290: GAIL Loss 0.254, Disc Loss 1.160
# Epoch 300: GAIL Loss 0.141, Disc Loss 0.891
# Epoch 310: GAIL Loss 0.139, Disc Loss 0.936
# Epoch 320: GAIL Loss 0.109, Disc Loss 0.857
# Epoch 330: GAIL Loss 0.104, Disc Loss 0.909
# Epoch 340: GAIL Loss 0.130, Disc Loss 0.891
# Epoch 350: GAIL Loss 0.105, Disc Loss 0.891
# Epoch 360: GAIL Loss 0.166, Disc Loss 0.946
# Epoch 370: GAIL Loss 0.183, Disc Loss 1.158
# Epoch 380: GAIL Loss 0.118, Disc Loss 0.929
# Epoch 390: GAIL Loss 0.121, Disc Loss 0.864
# Epoch 400: GAIL Loss 0.164, Disc Loss 0.888
# Epoch 410: GAIL Loss 0.101, Disc Loss 0.957
# Epoch 420: GAIL Loss 0.122, Disc Loss 1.016
# Epoch 430: GAIL Loss 0.138, Disc Loss 0.866
# Epoch 440: GAIL Loss 0.259, Disc Loss 1.178
# Epoch 450: GAIL Loss 0.123, Disc Loss 0.778
# Epoch 460: GAIL Loss 0.070, Disc Loss 0.969
# Epoch 470: GAIL Loss 0.105, Disc Loss 1.083
# Epoch 480: GAIL Loss 0.102, Disc Loss 0.925
# Epoch 490: GAIL Loss 0.123, Disc Loss 1.060
# Epoch 500: GAIL Loss 0.100, Disc Loss 0.962
# Epoch 510: GAIL Loss 0.140, Disc Loss 1.008
# Epoch 520: GAIL Loss 0.136, Disc Loss 0.882
# Epoch 530: GAIL Loss 0.095, Disc Loss 0.864
# Epoch 540: GAIL Loss 0.099, Disc Loss 0.900
# Epoch 550: GAIL Loss 0.101, Disc Loss 1.008
# Epoch 560: GAIL Loss 0.062, Disc Loss 0.939
# Epoch 570: GAIL Loss 0.134, Disc Loss 0.878
# Epoch 580: GAIL Loss 0.094, Disc Loss 0.879
# Epoch 590: GAIL Loss 0.092, Disc Loss 0.818
# Epoch 600: GAIL Loss 0.106, Disc Loss 0.841
# Epoch 610: GAIL Loss 0.106, Disc Loss 0.935
# Epoch 620: GAIL Loss 0.107, Disc Loss 0.776
# Epoch 630: GAIL Loss 0.110, Disc Loss 0.864
# Epoch 640: GAIL Loss 0.117, Disc Loss 0.826
# Epoch 650: GAIL Loss 0.140, Disc Loss 1.273
# Epoch 660: GAIL Loss 0.075, Disc Loss 0.845
# Epoch 670: GAIL Loss 0.082, Disc Loss 0.811
# Epoch 680: GAIL Loss 0.238, Disc Loss 1.032
# Epoch 690: GAIL Loss 0.072, Disc Loss 0.763
# Epoch 700: GAIL Loss 0.078, Disc Loss 0.936
# Epoch 710: GAIL Loss 0.120, Disc Loss 1.150
# Epoch 720: GAIL Loss 0.113, Disc Loss 0.819
# Epoch 730: GAIL Loss 0.075, Disc Loss 0.871
# Epoch 740: GAIL Loss 0.127, Disc Loss 0.708
# Epoch 750: GAIL Loss 0.104, Disc Loss 0.818
# Epoch 760: GAIL Loss 0.057, Disc Loss 0.766
# Epoch 770: GAIL Loss 0.090, Disc Loss 0.957
# Epoch 780: GAIL Loss 0.077, Disc Loss 0.991
# Epoch 790: GAIL Loss 0.092, Disc Loss 0.884
# Epoch 800: GAIL Loss 0.174, Disc Loss 1.009
# Epoch 810: GAIL Loss 0.090, Disc Loss 0.834
# Epoch 820: GAIL Loss 0.076, Disc Loss 0.762
# Epoch 830: GAIL Loss 0.080, Disc Loss 0.909
# Epoch 840: GAIL Loss 0.108, Disc Loss 0.780
# Epoch 850: GAIL Loss 0.161, Disc Loss 1.220
# Epoch 860: GAIL Loss 0.060, Disc Loss 0.894
# Epoch 870: GAIL Loss 0.068, Disc Loss 0.900
# Epoch 880: GAIL Loss 0.095, Disc Loss 0.934
# Epoch 890: GAIL Loss 0.067, Disc Loss 0.806
# Epoch 900: GAIL Loss 0.083, Disc Loss 1.089
# Epoch 910: GAIL Loss 0.070, Disc Loss 0.985
# Epoch 920: GAIL Loss 0.106, Disc Loss 1.097
# Epoch 930: GAIL Loss 0.090, Disc Loss 0.902
# Epoch 940: GAIL Loss 0.054, Disc Loss 0.944
# Epoch 950: GAIL Loss 0.063, Disc Loss 0.871
# Epoch 960: GAIL Loss 0.066, Disc Loss 0.916
# Epoch 970: GAIL Loss 0.057, Disc Loss 0.975
# Epoch 980: GAIL Loss 0.134, Disc Loss 1.475
# Epoch 990: GAIL Loss 0.073, Disc Loss 1.309
# Epoch 1000: GAIL Loss 0.050, Disc Loss 1.030
# Epoch 1010: GAIL Loss 0.094, Disc Loss 0.980
# Epoch 1020: GAIL Loss 0.050, Disc Loss 1.078
# Epoch 1030: GAIL Loss 0.080, Disc Loss 1.274
# Epoch 1040: GAIL Loss 0.044, Disc Loss 1.061
# Epoch 1050: GAIL Loss 0.049, Disc Loss 0.993
# Epoch 1060: GAIL Loss 0.064, Disc Loss 0.899
# Epoch 1070: GAIL Loss 0.091, Disc Loss 1.441
# Epoch 1080: GAIL Loss 0.067, Disc Loss 1.012
# Epoch 1090: GAIL Loss 0.078, Disc Loss 1.401
# Epoch 1100: GAIL Loss 0.078, Disc Loss 1.011
# Epoch 1110: GAIL Loss 0.080, Disc Loss 1.517
# Epoch 1120: GAIL Loss 0.095, Disc Loss 1.188
# Epoch 1130: GAIL Loss 0.069, Disc Loss 1.492
# Epoch 1140: GAIL Loss 0.088, Disc Loss 0.993
# Epoch 1150: GAIL Loss 0.056, Disc Loss 1.199
# Epoch 1160: GAIL Loss 0.050, Disc Loss 1.063
# Epoch 1170: GAIL Loss 0.060, Disc Loss 0.930
# Epoch 1180: GAIL Loss 0.093, Disc Loss 1.894
# Epoch 1190: GAIL Loss 0.041, Disc Loss 1.240
# Epoch 1200: GAIL Loss 0.027, Disc Loss 1.343
# Epoch 1210: GAIL Loss 0.059, Disc Loss 1.458
# Epoch 1220: GAIL Loss 0.066, Disc Loss 1.153
# Epoch 1230: GAIL Loss 0.056, Disc Loss 1.081
# Epoch 1240: GAIL Loss 0.126, Disc Loss 1.041
# Epoch 1250: GAIL Loss 0.055, Disc Loss 1.201
# Epoch 1260: GAIL Loss 0.051, Disc Loss 1.530
# Epoch 1270: GAIL Loss 0.050, Disc Loss 1.164
# Epoch 1280: GAIL Loss 0.061, Disc Loss 1.307
# Epoch 1290: GAIL Loss 0.065, Disc Loss 1.276
# Epoch 1300: GAIL Loss 0.076, Disc Loss 1.240
# Epoch 1310: GAIL Loss 0.058, Disc Loss 1.195
# Epoch 1320: GAIL Loss 0.061, Disc Loss 1.311
# Epoch 1330: GAIL Loss 0.051, Disc Loss 1.190
# Epoch 1340: GAIL Loss 0.062, Disc Loss 1.558
# Epoch 1350: GAIL Loss 0.085, Disc Loss 1.092
# Epoch 1360: GAIL Loss 0.072, Disc Loss 1.183
# Epoch 1370: GAIL Loss 0.100, Disc Loss 1.131
# Epoch 1380: GAIL Loss 0.040, Disc Loss 1.699
# Epoch 1390: GAIL Loss 0.081, Disc Loss 1.115
# Epoch 1400: GAIL Loss 0.058, Disc Loss 1.570
# Epoch 1410: GAIL Loss 0.049, Disc Loss 1.258
# Epoch 1420: GAIL Loss 0.060, Disc Loss 1.214
# Epoch 1430: GAIL Loss 0.019, Disc Loss 1.242
# Epoch 1440: GAIL Loss 0.056, Disc Loss 1.152
# Epoch 1450: GAIL Loss 0.068, Disc Loss 1.348
# Epoch 1460: GAIL Loss 0.060, Disc Loss 1.228
# Epoch 1470: GAIL Loss 0.053, Disc Loss 1.243
# Epoch 1480: GAIL Loss 0.029, Disc Loss 1.474
# Epoch 1490: GAIL Loss 0.069, Disc Loss 1.157
# Epoch 1500: GAIL Loss 0.056, Disc Loss 1.237
# Epoch 1510: GAIL Loss 0.029, Disc Loss 1.463
# Epoch 1520: GAIL Loss 0.040, Disc Loss 1.417
# Epoch 1530: GAIL Loss 0.033, Disc Loss 1.503
# Epoch 1540: GAIL Loss 0.083, Disc Loss 1.154
# Epoch 1550: GAIL Loss 0.043, Disc Loss 1.264
# Epoch 1560: GAIL Loss 0.051, Disc Loss 1.173
# Epoch 1570: GAIL Loss 0.044, Disc Loss 1.249
# Epoch 1580: GAIL Loss 0.079, Disc Loss 1.009
# Epoch 1590: GAIL Loss 0.029, Disc Loss 1.437
# Epoch 1600: GAIL Loss 0.039, Disc Loss 1.183
# Epoch 1610: GAIL Loss 0.062, Disc Loss 1.360
# Epoch 1620: GAIL Loss 0.062, Disc Loss 1.436
# Epoch 1630: GAIL Loss 0.041, Disc Loss 1.480
# Epoch 1640: GAIL Loss 0.080, Disc Loss 1.259
# Epoch 1650: GAIL Loss 0.038, Disc Loss 1.775
# Epoch 1660: GAIL Loss 0.078, Disc Loss 1.565
# Epoch 1670: GAIL Loss 0.032, Disc Loss 1.368
# Epoch 1680: GAIL Loss 0.052, Disc Loss 1.499
# Epoch 1690: GAIL Loss 0.048, Disc Loss 1.106
# Epoch 1700: GAIL Loss 0.080, Disc Loss 1.139
# Epoch 1710: GAIL Loss 0.043, Disc Loss 1.186
# Epoch 1720: GAIL Loss 0.076, Disc Loss 1.044
# Epoch 1730: GAIL Loss 0.092, Disc Loss 1.008
# Epoch 1740: GAIL Loss 0.061, Disc Loss 1.221
# Epoch 1750: GAIL Loss 0.085, Disc Loss 1.157
# Epoch 1760: GAIL Loss 0.037, Disc Loss 1.161
# Epoch 1770: GAIL Loss 0.041, Disc Loss 1.142
# Epoch 1780: GAIL Loss 0.074, Disc Loss 1.162
# Epoch 1790: GAIL Loss 0.043, Disc Loss 1.180
# Epoch 1800: GAIL Loss 0.048, Disc Loss 1.432
# Epoch 1810: GAIL Loss 0.026, Disc Loss 1.394
# Epoch 1820: GAIL Loss 0.102, Disc Loss 1.121
# Epoch 1830: GAIL Loss 0.054, Disc Loss 1.474
# Epoch 1840: GAIL Loss 0.055, Disc Loss 1.260
# Epoch 1850: GAIL Loss 0.048, Disc Loss 1.092
# Epoch 1860: GAIL Loss 0.099, Disc Loss 1.109
# Epoch 1870: GAIL Loss 0.049, Disc Loss 1.135
# Epoch 1880: GAIL Loss 0.049, Disc Loss 1.319
# Epoch 1890: GAIL Loss 0.070, Disc Loss 1.135
# Epoch 1900: GAIL Loss 0.051, Disc Loss 1.327
# Epoch 1910: GAIL Loss 0.074, Disc Loss 1.194
# Epoch 1920: GAIL Loss 0.041, Disc Loss 1.444
# Epoch 1930: GAIL Loss 0.025, Disc Loss 1.136
# Epoch 1940: GAIL Loss 0.081, Disc Loss 1.299
# Epoch 1950: GAIL Loss 0.033, Disc Loss 1.274
# Epoch 1960: GAIL Loss 0.056, Disc Loss 1.452
# Epoch 1970: GAIL Loss 0.033, Disc Loss 1.500
# Epoch 1980: GAIL Loss 0.041, Disc Loss 1.318
# Epoch 1990: GAIL Loss 0.041, Disc Loss 1.161
# Epoch 2000: GAIL Loss 0.044, Disc Loss 1.194
# Epoch 2010: GAIL Loss 0.083, Disc Loss 1.078
# Epoch 2020: GAIL Loss 0.038, Disc Loss 1.463
# Epoch 2030: GAIL Loss 0.013, Disc Loss 1.244
# Epoch 2040: GAIL Loss 0.073, Disc Loss 1.028
# Epoch 2050: GAIL Loss 0.027, Disc Loss 1.372
# Epoch 2060: GAIL Loss 0.053, Disc Loss 1.403
# Epoch 2070: GAIL Loss 0.043, Disc Loss 1.453
# Epoch 2080: GAIL Loss 0.057, Disc Loss 1.192
# Epoch 2090: GAIL Loss 0.036, Disc Loss 1.306
# Epoch 2100: GAIL Loss 0.078, Disc Loss 1.024
# Epoch 2110: GAIL Loss 0.036, Disc Loss 1.323
# Epoch 2120: GAIL Loss 0.031, Disc Loss 1.511
# Epoch 2130: GAIL Loss 0.038, Disc Loss 1.496
# Epoch 2140: GAIL Loss 0.107, Disc Loss 1.222
# Epoch 2150: GAIL Loss 0.044, Disc Loss 1.133
# Epoch 2160: GAIL Loss 0.034, Disc Loss 1.465
# Epoch 2170: GAIL Loss 0.062, Disc Loss 1.335
# Epoch 2180: GAIL Loss 0.049, Disc Loss 1.123
# Epoch 2190: GAIL Loss 0.066, Disc Loss 1.147
# Epoch 2200: GAIL Loss 0.041, Disc Loss 1.336
# Epoch 2210: GAIL Loss 0.027, Disc Loss 1.299
# Epoch 2220: GAIL Loss 0.033, Disc Loss 1.390
# Epoch 2230: GAIL Loss 0.061, Disc Loss 1.325
# Epoch 2240: GAIL Loss 0.040, Disc Loss 1.126
# Epoch 2250: GAIL Loss 0.030, Disc Loss 1.479
# Epoch 2260: GAIL Loss 0.053, Disc Loss 1.157
# Epoch 2270: GAIL Loss 0.027, Disc Loss 1.318
# Epoch 2280: GAIL Loss 0.040, Disc Loss 1.401
# Epoch 2290: GAIL Loss 0.037, Disc Loss 1.435
# Epoch 2300: GAIL Loss 0.055, Disc Loss 1.450
# Epoch 2310: GAIL Loss 0.065, Disc Loss 1.454
# Epoch 2320: GAIL Loss 0.080, Disc Loss 1.183
# Epoch 2330: GAIL Loss 0.033, Disc Loss 1.441
# Epoch 2340: GAIL Loss 0.032, Disc Loss 1.371
# Epoch 2350: GAIL Loss 0.049, Disc Loss 1.247
# Epoch 2360: GAIL Loss 0.058, Disc Loss 1.503
# Epoch 2370: GAIL Loss 0.045, Disc Loss 1.237
# Epoch 2380: GAIL Loss 0.016, Disc Loss 1.536
# Epoch 2390: GAIL Loss 0.050, Disc Loss 1.147
# Epoch 2400: GAIL Loss 0.035, Disc Loss 1.293
# Epoch 2410: GAIL Loss 0.039, Disc Loss 1.288
# Epoch 2420: GAIL Loss 0.054, Disc Loss 1.131
# Epoch 2430: GAIL Loss 0.092, Disc Loss 1.144
# Epoch 2440: GAIL Loss 0.038, Disc Loss 1.400
# Epoch 2450: GAIL Loss 0.047, Disc Loss 1.229
# Epoch 2460: GAIL Loss 0.051, Disc Loss 1.237
# Epoch 2470: GAIL Loss 0.061, Disc Loss 1.337
# Epoch 2480: GAIL Loss 0.064, Disc Loss 1.169
# Epoch 2490: GAIL Loss 0.025, Disc Loss 1.252
# Epoch 2500: GAIL Loss 0.058, Disc Loss 1.216
# Epoch 2510: GAIL Loss 0.059, Disc Loss 1.303
# Epoch 2520: GAIL Loss 0.055, Disc Loss 1.305
# Epoch 2530: GAIL Loss 0.057, Disc Loss 1.261
# Epoch 2540: GAIL Loss 0.031, Disc Loss 1.380
# Epoch 2550: GAIL Loss 0.065, Disc Loss 1.182
# Epoch 2560: GAIL Loss 0.020, Disc Loss 1.193
# Epoch 2570: GAIL Loss 0.044, Disc Loss 1.368
# Epoch 2580: GAIL Loss 0.043, Disc Loss 1.375
# Epoch 2590: GAIL Loss 0.046, Disc Loss 1.362
# Epoch 2600: GAIL Loss 0.045, Disc Loss 1.353
# Epoch 2610: GAIL Loss 0.039, Disc Loss 1.204
# Epoch 2620: GAIL Loss 0.079, Disc Loss 1.119
# Epoch 2630: GAIL Loss 0.046, Disc Loss 1.320
# Epoch 2640: GAIL Loss 0.052, Disc Loss 1.189
# Epoch 2650: GAIL Loss 0.032, Disc Loss 1.465
# Epoch 2660: GAIL Loss 0.014, Disc Loss 1.238
# Epoch 2670: GAIL Loss 0.025, Disc Loss 1.412
# Epoch 2680: GAIL Loss 0.017, Disc Loss 1.237
# Epoch 2690: GAIL Loss 0.033, Disc Loss 1.545
# Epoch 2700: GAIL Loss 0.056, Disc Loss 1.168
# Epoch 2710: GAIL Loss 0.029, Disc Loss 1.395
# Epoch 2720: GAIL Loss 0.049, Disc Loss 1.111
# Epoch 2730: GAIL Loss 0.029, Disc Loss 1.524
# Epoch 2740: GAIL Loss 0.031, Disc Loss 1.184
# Epoch 2750: GAIL Loss 0.034, Disc Loss 1.386
# Epoch 2760: GAIL Loss 0.082, Disc Loss 1.151
# Epoch 2770: GAIL Loss 0.058, Disc Loss 1.373
# Epoch 2780: GAIL Loss 0.036, Disc Loss 1.407
# Epoch 2790: GAIL Loss 0.030, Disc Loss 1.183
# Epoch 2800: GAIL Loss 0.009, Disc Loss 1.410
# Epoch 2810: GAIL Loss 0.034, Disc Loss 1.135
# Epoch 2820: GAIL Loss 0.046, Disc Loss 1.384
# Epoch 2830: GAIL Loss 0.059, Disc Loss 1.552
# Epoch 2840: GAIL Loss 0.033, Disc Loss 1.242
# Epoch 2850: GAIL Loss 0.037, Disc Loss 1.226
# Epoch 2860: GAIL Loss 0.030, Disc Loss 1.404
# Epoch 2870: GAIL Loss 0.030, Disc Loss 1.438
# Epoch 2880: GAIL Loss 0.015, Disc Loss 1.341
# Epoch 2890: GAIL Loss 0.036, Disc Loss 1.473
# Epoch 2900: GAIL Loss 0.015, Disc Loss 1.343
# Epoch 2910: GAIL Loss 0.034, Disc Loss 1.527
# Epoch 2920: GAIL Loss 0.053, Disc Loss 1.320
# Epoch 2930: GAIL Loss 0.043, Disc Loss 1.382
# Epoch 2940: GAIL Loss 0.044, Disc Loss 1.210
# Epoch 2950: GAIL Loss 0.020, Disc Loss 1.348
# Epoch 2960: GAIL Loss 0.012, Disc Loss 1.298
# Epoch 2970: GAIL Loss 0.058, Disc Loss 1.232
# Epoch 2980: GAIL Loss 0.043, Disc Loss 1.382
# Epoch 2990: GAIL Loss 0.054, Disc Loss 1.304

# %% [markdown]
# Протестируйте ваш алгоритм

# %%
def test_policy(env, policy):
    for _ in range(10):
        obs, _ = env.reset()
        done = False
        total_reward = 0
        t = 0
        while not done:
            # Обработайте obs если планируете добавлять в него t
            augmented_obs = np.concatenate([
                obs,
                [np.sin(t / 10), np.cos(t / 10)]
            ]).astype(np.float32)

            obs_tensor = torch.tensor(augmented_obs, dtype=torch.float32).unsqueeze(0)
            action = policy.get_action(obs_tensor)
            next_obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            obs = next_obs
            total_reward += reward
            t += 1
        print(total_reward)

# %%
env = gym.make("MountainCar-v0", render_mode=None)
test_policy(env, policy)
env.close()
# Out:
# -200.0
# -156.0
# -138.0
# -200.0
# -189.0
# -141.0
# -117.0
# -119.0
# -186.0
# -143.0
